# %%
# import dependencies
import pandas as pd
import numpy as np
from citipy import citipy

# %%
#Create set of 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000,high=90.000, size=2000)
lngs = np.random.uniform(low=180.000,high=-180.000, size=2000)
coordinates = list(zip(lats, lngs))

# %%
lats
# Out:
# array([-73.20552771,  28.33612413,  66.7068206 , ...,  39.90787503,
#         38.32334024, -72.6005392 ])

# %%
lngs
# Out:
# array([  98.28265151,  -11.48621463, -126.70389223, ...,   70.31618653,
#         -48.42104219,  -32.15483586])

# %%
#Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
cities
# Out:
# ['albany',
#  'arrecife',
#  'norman wells',
#  'ushuaia',
#  'saskylakh',
#  'lavrentiya',
#  'san policarpo',
#  'hilo',
#  'mataura',
#  'mehamn',
#  'port alfred',
#  'waldoboro',
#  'krosno',
#  'busselton',
#  'rikitea',
#  'hobart',
#  'san cristobal',
#  'atuona',
#  'amahai',
#  'chumikan',
#  'severo-kurilsk',
#  'cape town',
#  'okhotsk',
#  'butaritari',
#  'cravo norte',
#  'mangan',
#  'aklavik',
#  'san jeronimo',
#  'maunabo',
#  'san ramon de la nueva oran',
#  'abnub',
#  'umzimvubu',
#  'madras',
#  'bluff',
#  'avon park',
#  'yeniseysk',
#  'akom',
#  'dunedin',
#  'brae',
#  'esperance',
#  'bull savanna',
#  'trinidad',
#  'huarmey',
#  'muskogee',
#  'vostok',
#  'richards bay',
#  'maragogi',
#  'upernavik',
#  'avarua',
#  'punta arenas',
#  'whitehorse',
#  'iqaluit',
#  'cahors',
#  'vaini',
#  'attawapiskat',
#  'katsuura',
#  'tessalit',
#  'tiksi',
#  'armacao dos buzios',
#  'salalah',
#  'buariki',
#  'tuktoyaktuk',
#  'zyryanka',
#  'kribi',
#  'hami',
#  'yellowknife',
#  'minjur',
#  'illoqqortoormiut',
#  'great yarmouth',
#  'vaitupu',
#  'svetlogorsk',
#  'souillac',
#  'santa rosa',
#  'canandaigua',
#  'saint-francois',
#  'grafton',
#  'hithadhoo',
#  'poum',
#  'ankazobe',
#  'taksimo',
#  'taolanaro',
#  'bengkulu',
#  'northam',
#  'hermanus',
#  'port macquarie',
#  'puerto escondido',
#  'mentougou',
#  'jamestown',
#  'cherskiy',
#  'isangel',
#  'broome',
#  'misratah',
#  'new norfolk',
#  'kapaa',
#  'puerto ayora',
#  'kavieng',
#  'verkhnevilyuysk',
#  'prieska',
#  'port elizabeth',
#  'barrow',
#  'chokurdakh',
#  'tsihombe',
#  'kosa',
#  'bowen',
#  'mar del plata',
#  'buraydah',
#  'codrington',
#  'biala podlaska',
#  'pangnirtung',
#  'saint-philippe',
#  'airai',
#  'kaitangata',
#  'sahbuz',
#  'belmonte',
#  'kemijarvi',
#  'barentsburg',
#  'miranorte',
#  'kahului',
#  'bontang',
#  'lolua',
#  'schweinfurt',
#  'yerbogachen',
#  'roald',
#  'mahebourg',
#  'saint-pierre',
#  'lannion',
#  'sibu',
#  'tra vinh',
#  'ostrovnoy',
#  'saint george',
#  'nevsehir',
#  'glendive',
#  'dondo',
#  'praya',
#  'cabedelo',
#  'belushya guba',
#  'saldanha',
#  'waipawa',
#  'pitimbu',
#  'marsa matruh',
#  'carnarvon',
#  'clyde river',
#  'lebu',
#  'thompson',
#  'port lincoln',
#  'berlevag',
#  'craig',
#  'abashiri',
#  'mergui',
#  'kodiak',
#  'nizhneyansk',
#  'acari',
#  'sentyabrskiy',
#  'jinxiang',
#  'tandur',
#  'laguna',
#  'pevek',
#  'komsomolskiy',
#  'kargasok',
#  'namibe',
#  'faanui',
#  'metro',
#  'pangai',
#  'bahia de caraquez',
#  'lagoa',
#  'vila velha',
#  'provideniya',
#  'havre-saint-pierre',
#  'wajir',
#  'oktyabrskiy',
#  'touros',
#  'udachnyy',
#  'makakilo city',
#  'noceto',
#  'santa cruz cabralia',
#  'sumenep',
#  'klyuchi',
#  'ulladulla',
#  'nikolskoye',
#  'harper',
#  'kichera',
#  'road town',
#  'ciampea',
#  'grand river south east',
#  'cidreira',
#  'anaconda',
#  'linchuan',
#  'sepolno krajenskie',
#  'kalamb',
#  'ixtapa',
#  'maghama',
#  'arraial do cabo',
#  'ruatoria',
#  'belozerskoye',
#  'black river',
#  'east london',
#  'bethel',
#  'aripuana',
#  'cabo san lucas',
#  'honningsvag',
#  'ugoofaaru',
#  'qiongshan',
#  'atasu',
#  'bubaque',
#  'vaxjo',
#  'portland',
#  'chapais',
#  'kokoda',
#  'mys shmidta',
#  'depalpur',
#  'harindanga',
#  'mopipi',
#  'jacareacanga',
#  'umm lajj',
#  'sakata',
#  'hasaki',
#  'thunder bay',
#  'skibbereen',
#  'ponta do sol',
#  'saleaula',
#  'ust-tsilma',
#  'banjar',
#  'belle glade',
#  'sioux lookout',
#  'londiani',
#  'honavar',
#  'namatanai',
#  'iquitos',
#  'jalu',
#  'longyearbyen',
#  'samagaltay',
#  'qaanaaq',
#  'luderitz',
#  'katangli',
#  'ribeira grande',
#  'sidi bu zayd',
#  'kytlym',
#  'lenart',
#  'bambous virieux',
#  'karaul',
#  'coihaique',
#  'torbay',
#  'georgetown',
#  'alofi',
#  'finschhafen',
#  'springdale',
#  'dingle',
#  'chauk',
#  'padang',
#  'haines junction',
#  'yenagoa',
#  'ferzikovo',
#  'chuy',
#  'angoche',
#  'maun',
#  'mayumba',
#  'bredasdorp',
#  'sao joao da barra',
#  'marshall',
#  'port blair',
#  'tasiilaq',
#  'opuwo',
#  'mantua',
#  'malwan',
#  'angatuba',
#  'moose factory',
#  'nautla',
#  'quepos',
#  'jiddah',
#  'vao',
#  'plettenberg bay',
#  'gorno-altaysk',
#  'sao filipe',
#  'baykit',
#  'lemoore',
#  'sitka',
#  'marang',
#  'preobrazheniye',
#  'takoradi',
#  'vila franca do campo',
#  'rock springs',
#  'soskovo',
#  'kharan',
#  'kruisfontein',
#  'piro',
#  'ketchikan',
#  'constitucion',
#  'susaki',
#  'banda aceh',
#  'alpena',
#  'san-pedro',
#  'yeppoon',
#  'tual',
#  'gallup',
#  'angoram',
#  'changping',
#  'verkhoyansk',
#  'flinders',
#  'san patricio',
#  'yarmouth',
#  'canoinhas',
#  'gat',
#  'swellendam',
#  'shimanovsk',
#  'artyom',
#  'tuatapere',
#  'naze',
#  'meulaboh',
#  'guerrero negro',
#  'toora-khem',
#  'zykovo',
#  'nome',
#  'mercedes',
#  'antofagasta',
#  'chilliwack',
#  'palabuhanratu',
#  'saravena',
#  'diego de almagro',
#  'ancud',
#  'senador jose porfirio',
#  'black forest',
#  'mago',
#  'half moon bay',
#  'acuna',
#  'bonthe',
#  'santiago de cao',
#  'klaksvik',
#  'varhaug',
#  'san ramon',
#  'fairbanks',
#  'atar',
#  'khabary',
#  'khatanga',
#  'alekseyevsk',
#  'asyut',
#  'abha',
#  'bilma',
#  'victoria',
#  'san juan tecuaco',
#  'egvekinot',
#  'korla',
#  'rio grande',
#  'ambon',
#  'truth or consequences',
#  'pahrump',
#  'zelenogorskiy',
#  'hamilton',
#  'nanortalik',
#  'west wendover',
#  'kaoma',
#  'dikson',
#  'nouadhibou',
#  'mount isa',
#  'vanimo',
#  'la palma',
#  'castro',
#  'broken hill',
#  'ilulissat',
#  'marawi',
#  'sola',
#  'kiruna',
#  'buin',
#  'babanusah',
#  'taltal',
#  'teya',
#  'lata',
#  'quatre cocos',
#  'concepcion',
#  'oregon',
#  'turukhansk',
#  'boa vista',
#  'solnechnyy',
#  'bathsheba',
#  'biltine',
#  'salinopolis',
#  'ballina',
#  'satitoa',
#  'whitianga',
#  'kenscoff',
#  'yashkino',
#  'shenjiamen',
#  'oistins',
#  'cornesti',
#  'batagay-alyta',
#  'idlib',
#  'ville-marie',
#  'shingu',
#  'denizli',
#  'smithers',
#  'sindor',
#  'inirida',
#  'marienburg',
#  'damietta',
#  'hambantota',
#  'sinegorskiy',
#  'salinas',
#  'khaniotis',
#  'bela',
#  'progreso',
#  'namtsy',
#  'homer',
#  'sinnamary',
#  'olinda',
#  'tazovskiy',
#  'mitu',
#  'petrovskaya',
#  'avera',
#  'lithgow',
#  'sinfra',
#  'alcaniz',
#  'griffith',
#  'borovoy',
#  'miyako',
#  'sigli',
#  'batagay',
#  'baker city',
#  'khandyga',
#  'akyab',
#  'solovetskiy',
#  'morro bay',
#  'amderma',
#  'rocha',
#  'kropotkin',
#  'luorong',
#  'tecoanapa',
#  'srednekolymsk',
#  'leningradskiy',
#  'sorvag',
#  'seoul',
#  'samusu',
#  'qaqortoq',
#  'strathpeffer',
#  'nurota',
#  'nalut',
#  'qasigiannguit',
#  'menongue',
#  'tonj',
#  'shubarkuduk',
#  'port-gentil',
#  'manitouwadge',
#  'pietersburg',
#  'mocambique',
#  'north platte',
#  'port hardy',
#  'louisbourg',
#  'ati',
#  'shihezi',
#  'kangaatsiaq',
#  'lixourion',
#  'verkhoturye',
#  'simao',
#  'chichihualco',
#  'lompoc',
#  'cheyenne',
#  'lahat',
#  'buala',
#  'aksarka',
#  'ostersund',
#  'ravar',
#  'tukrah',
#  'manuk mangkaw',
#  'viesca',
#  'shyroke',
#  'yinchuan',
#  'heihe',
#  'guymon',
#  'rio gallegos',
#  'corpus christi',
#  'neiafu',
#  'stoyba',
#  'jinchang',
#  'la romana',
#  'te anau',
#  'yazd',
#  'burica',
#  'margate',
#  'goure',
#  'marcona',
#  'seymchan',
#  'evensk',
#  'richard toll',
#  'nantucket',
#  'san matias',
#  'grindavik',
#  'fort nelson',
#  'kavaratti',
#  'verkhovye',
#  'suez',
#  'ingham',
#  'rawson',
#  'naryan-mar',
#  'bosanska gradiska',
#  'necochea',
#  'puri',
#  'gidam',
#  'tchaourou',
#  'lebyazhye',
#  'trail',
#  'dwarka',
#  'kuche',
#  'ulaanbaatar',
#  'karratha',
#  'brasileia',
#  'tezu',
#  'voyvozh',
#  'galle',
#  'cervo',
#  'jesi',
#  'kieta',
#  'bahia blanca',
#  'kukes',
#  'nemuro',
#  'port hedland',
#  'pisco',
#  'shalinskoye',
#  'thaba nchu',
#  'camacha',
#  'suleja',
#  'tiarei',
#  'qunduz',
#  'bereda',
#  'bulolo',
#  'ahipara',
#  'issoire',
#  'bolshaya atnya',
#  'semnan',
#  'eustaquio lopez',
#  'eyrarbakki',
#  'singaraja',
#  'thayetmyo',
#  'wajima',
#  'vaasa',
#  'umm kaddadah',
#  'anadyr',
#  'aswan',
#  'tokzar',
#  'datong',
#  'ploufragan',
#  'mildura',
#  'panzhihua',
#  'bridlington',
#  'san quintin',
#  'huilong',
#  'ulkan',
#  'talnakh',
#  'zhaotong',
#  'arroyo',
#  'teahupoo',
#  'pringsewu',
#  'khao wong',
#  'shetpe',
#  'doctor pedro p. pena',
#  'itarema',
#  'senftenberg',
#  'grand gaube',
#  'taburao',
#  'molina',
#  'tsiroanomandidy',
#  'acapulco',
#  'hofn',
#  'wulanhaote',
#  'sydney',
#  'mana',
#  'les escoumins',
#  'cururupu',
#  'yining',
#  'okato',
#  'hurghada',
#  'eureka',
#  'mananjary',
#  'cosala',
#  'paradwip',
#  'alice springs',
#  'peniche',
#  'felidhoo',
#  'geraldton',
#  'rurrenabaque',
#  'muli',
#  'khorixas',
#  'pochutla',
#  'vila',
#  'teguise',
#  'camacupa',
#  'chaumont',
#  'matadi',
#  'kindu',
#  'vestmannaeyjar',
#  'ornskoldsvik',
#  'saint-raphael',
#  'asfi',
#  'carutapera',
#  'fuyu',
#  'sinkat',
#  'kirakira',
#  'goundi',
#  'quthing',
#  'lubango',
#  'waitati',
#  'adrar',
#  'san rafael',
#  'itoman',
#  'tres arroyos',
#  'baruun-urt',
#  'vierzon',
#  'sorland',
#  'fortuna',
#  'revelstoke',
#  'bud',
#  'tigzirt',
#  'amazar',
#  'fernie',
#  'aktau',
#  'luena',
#  'simpang',
#  'mariestad',
#  'togul',
#  'ocampo',
#  'amapa',
#  'belyy yar',
#  'la paz',
#  'oktyabrskoye',
#  'chernolesskoye',
#  'mount gambier',
#  'moba',
#  'nguiu',
#  'bulgan',
#  'inuvik',
#  'santa maria',
#  'jinxi',
#  'kulhudhuffushi',
#  'ballater',
#  'araguatins',
#  'maceio',
#  'lusambo',
#  'taoudenni',
#  'bijar',
#  'yanchukan',
#  'mugumu',
#  'loma bonita',
#  'miastko',
#  'port-cartier',
#  'atwater',
#  'harrison',
#  'xambioa',
#  'deputatskiy',
#  'strezhevoy',
#  'assiniboia',
#  'atambua',
#  'hailar',
#  'novikovo',
#  'saint anthony',
#  'bitung',
#  'byron bay',
#  'redcar',
#  'waddan',
#  'sawakin',
#  'kayes',
#  'san nicolas',
#  'juegang',
#  'beloha',
#  'aleksandrov gay',
#  'caravelas',
#  'sur',
#  'west bay',
#  'izhma',
#  'chernyshevskiy',
#  'senanga',
#  'auki',
#  'north bend',
#  'odweyne',
#  'mehran',
#  'larsnes',
#  'singaparna',
#  'barmer',
#  'saint-jerome',
#  'lorengau',
#  'baft',
#  'payo',
#  'caraballeda',
#  'zaranj',
#  'coquimbo',
#  'kadykchan',
#  'bandarbeyla',
#  'karpogory',
#  'batemans bay',
#  'gorkovskoye',
#  'beringovskiy',
#  'baijiantan',
#  'porto belo',
#  'olavarria',
#  'boyolangu',
#  'zhangjiakou',
#  'scottsburgh',
#  'fomboni',
#  'silopi',
#  'labuhan',
#  'santa maria da boa vista',
#  'crewe',
#  'cacu',
#  'agadez',
#  'aitape',
#  'hals',
#  'athabasca',
#  'cayenne',
#  'estrela',
#  'ewo',
#  'port moresby',
#  'leh',
#  'mandalgovi',
#  'mahon',
#  'kasongo-lunda',
#  'abu kamal',
#  'mbini',
#  'kushima',
#  'samalaeulu',
#  'bilibino',
#  'walvis bay',
#  'maniitsoq',
#  'baherden',
#  'darnah',
#  'orebro',
#  'liverpool',
#  'mogadishu',
#  'gamba',
#  'lethem',
#  'ponta delgada',
#  'vestmanna',
#  'wuwei',
#  'sar-e pul',
#  'kuala terengganu',
#  'thinadhoo',
#  'lekoni',
#  'rolim de moura',
#  'sabha',
#  'santa eulalia del rio',
#  'dzhebariki-khaya',
#  'firminy',
#  'yuzhno-yeniseyskiy',
#  'ust-nera',
#  'pandan',
#  'yulara',
#  'pingliang',
#  'fatehgarh',
#  'hobyo',
#  'marzuq',
#  'inhambane',
#  'guiglo',
#  'jiangyou',
#  'betare oya',
#  'bobcaygeon',
#  'miandrivazo',
#  'talcahuano',
#  'isla mujeres',
#  'wanning',
#  'pentecoste',
#  'henties bay',
#  'phan rang',
#  'gravdal',
#  'cordoba',
#  'mayo',
#  'ileza',
#  'sabang',
#  'vorukh']

# %%
# Import the requests library.
import requests

# %%
# Import the API key
from config import weather_api_key
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# Starting URL for Weather Map API Call.
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "dc3c1943565087f7363d11b298a47885"
#print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc3c1943565087f7363d11b298a47885

# %%
city_url = query_url + "albany"
testing = requests.get(city_url).json()
testing
# Out:
# {'coord': {'lon': -73.97, 'lat': 42.6},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 74.48,
#   'feels_like': 71.11,
#   'temp_min': 73,
#   'temp_max': 75.99,
#   'pressure': 1018,
#   'humidity': 32},
#  'visibility': 10000,
#  'wind': {'speed': 3, 'deg': 249, 'gust': 11.01},
#  'clouds': {'all': 7},
#  'dt': 1599327501,
#  'sys': {'type': 3,
#   'id': 19530,
#   'country': 'US',
#   'sunrise': 1599301544,
#   'sunset': 1599348209},
#  'timezone': -14400,
#  'id': 5106841,
#  'name': 'Albany',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = query_url + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                            })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | arrecife
# Processing Record 3 of Set 1 | norman wells
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | saskylakh
# Processing Record 6 of Set 1 | lavrentiya
# Processing Record 7 of Set 1 | san policarpo
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | mehamn
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | waldoboro
# Processing Record 13 of Set 1 | krosno
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | san cristobal
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | amahai
# Processing Record 20 of Set 1 | chumikan
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | okhotsk
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | cravo norte
# Processing Record 26 of Set 1 | mangan
# Processing Record 27 of Set 1 | aklavik
# Processing Record 28 of Set 1 | san jeronimo
# Processing Record 29 of Set 1 | maunabo
# Processing Record 30 of Set 1 | san ramon de la nueva oran
# Processing Record 31 of Set 1 | abnub
# Processing Record 32 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 1 | madras
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | avon park
# Processing Record 36 of Set 1 | yeniseysk
# Processing Record 37 of Set 1 | akom
# Processing Record 38 of Set 1 | dunedin
# Processing Record 39 of Set 1 | brae
# Processing Record 40 of Set 1 | esperance
# Processing Record 41 of Set 1 | bull savanna
# Processing Record 42 of Set 1 | trinidad
# Processing Record 43 of Set 1 | huarmey
# Processing Record 44 of Set 1 | muskogee
# Processing Record 45 of Set 1 | vostok
# Processing Record 46 of Set 1 | richards bay
# Processing Record 47 of Set 1 | maragogi
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | whitehorse
# Processing Record 2 of Set 2 | iqaluit
# Processing Record 3 of Set 2 | cahors
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | katsuura
# Processing Record 7 of Set 2 | tessalit
# Processing Record 8 of Set 2 | tiksi
# Processing Record 9 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 10 of Set 2 | salalah
# Processing Record 11 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | zyryanka
# Processing Record 14 of Set 2 | kribi
# Processing Record 15 of Set 2 | hami
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | minjur
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | great yarmouth
# Processing Record 20 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 2 | svetlogorsk
# Processing Record 22 of Set 2 | souillac
# Processing Record 23 of Set 2 | santa rosa
# Processing Record 24 of Set 2 | canandaigua
# Processing Record 25 of Set 2 | saint-francois
# Processing Record 26 of Set 2 | grafton
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | poum
# Processing Record 29 of Set 2 | ankazobe
# Processing Record 30 of Set 2 | taksimo
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | northam
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | port macquarie
# Processing Record 36 of Set 2 | puerto escondido
# Processing Record 37 of Set 2 | mentougou
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | isangel
# Processing Record 41 of Set 2 | broome
# Processing Record 42 of Set 2 | misratah
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | verkhnevilyuysk
# Processing Record 48 of Set 2 | prieska
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 3 | kosa
# Processing Record 4 of Set 3 | bowen
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | buraydah
# Processing Record 7 of Set 3 | codrington
# Processing Record 8 of Set 3 | biala podlaska
# Processing Record 9 of Set 3 | pangnirtung
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | airai
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | sahbuz
# Processing Record 14 of Set 3 | belmonte
# Processing Record 15 of Set 3 | kemijarvi
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | miranorte
# City not found. Skipping...
# Processing Record 18 of Set 3 | kahului
# Processing Record 19 of Set 3 | bontang
# Processing Record 20 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 3 | schweinfurt
# Processing Record 22 of Set 3 | yerbogachen
# Processing Record 23 of Set 3 | roald
# Processing Record 24 of Set 3 | mahebourg
# Processing Record 25 of Set 3 | saint-pierre
# Processing Record 26 of Set 3 | lannion
# Processing Record 27 of Set 3 | sibu
# Processing Record 28 of Set 3 | tra vinh
# Processing Record 29 of Set 3 | ostrovnoy
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | nevsehir
# Processing Record 32 of Set 3 | glendive
# Processing Record 33 of Set 3 | dondo
# Processing Record 34 of Set 3 | praya
# Processing Record 35 of Set 3 | cabedelo
# Processing Record 36 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | waipawa
# Processing Record 39 of Set 3 | pitimbu
# Processing Record 40 of Set 3 | marsa matruh
# Processing Record 41 of Set 3 | carnarvon
# Processing Record 42 of Set 3 | clyde river
# Processing Record 43 of Set 3 | lebu
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | port lincoln
# Processing Record 46 of Set 3 | berlevag
# Processing Record 47 of Set 3 | craig
# Processing Record 48 of Set 3 | abashiri
# Processing Record 49 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 4 | acari
# Processing Record 3 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | jinxiang
# Processing Record 5 of Set 4 | tandur
# Processing Record 6 of Set 4 | laguna
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | komsomolskiy
# Processing Record 9 of Set 4 | kargasok
# Processing Record 10 of Set 4 | namibe
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | metro
# Processing Record 13 of Set 4 | pangai
# Processing Record 14 of Set 4 | bahia de caraquez
# Processing Record 15 of Set 4 | lagoa
# Processing Record 16 of Set 4 | vila velha
# Processing Record 17 of Set 4 | provideniya
# Processing Record 18 of Set 4 | havre-saint-pierre
# Processing Record 19 of Set 4 | wajir
# Processing Record 20 of Set 4 | oktyabrskiy
# Processing Record 21 of Set 4 | touros
# Processing Record 22 of Set 4 | udachnyy
# Processing Record 23 of Set 4 | makakilo city
# Processing Record 24 of Set 4 | noceto
# Processing Record 25 of Set 4 | santa cruz cabralia
# Processing Record 26 of Set 4 | sumenep
# Processing Record 27 of Set 4 | klyuchi
# Processing Record 28 of Set 4 | ulladulla
# Processing Record 29 of Set 4 | nikolskoye
# Processing Record 30 of Set 4 | harper
# Processing Record 31 of Set 4 | kichera
# Processing Record 32 of Set 4 | road town
# Processing Record 33 of Set 4 | ciampea
# Processing Record 34 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | anaconda
# Processing Record 37 of Set 4 | linchuan
# City not found. Skipping...
# Processing Record 38 of Set 4 | sepolno krajenskie
# Processing Record 39 of Set 4 | kalamb
# Processing Record 40 of Set 4 | ixtapa
# Processing Record 41 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 42 of Set 4 | arraial do cabo
# Processing Record 43 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 4 | belozerskoye
# Processing Record 45 of Set 4 | black river
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | bethel
# Processing Record 48 of Set 4 | aripuana
# Processing Record 49 of Set 4 | cabo san lucas
# Processing Record 50 of Set 4 | honningsvag
# Processing Record 1 of Set 5 | ugoofaaru
# Processing Record 2 of Set 5 | qiongshan
# Processing Record 3 of Set 5 | atasu
# Processing Record 4 of Set 5 | bubaque
# Processing Record 5 of Set 5 | vaxjo
# Processing Record 6 of Set 5 | portland
# Processing Record 7 of Set 5 | chapais
# Processing Record 8 of Set 5 | kokoda
# Processing Record 9 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 5 | depalpur
# Processing Record 11 of Set 5 | harindanga
# Processing Record 12 of Set 5 | mopipi
# Processing Record 13 of Set 5 | jacareacanga
# Processing Record 14 of Set 5 | umm lajj
# Processing Record 15 of Set 5 | sakata
# Processing Record 16 of Set 5 | hasaki
# Processing Record 17 of Set 5 | thunder bay
# Processing Record 18 of Set 5 | skibbereen
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 5 | ust-tsilma
# Processing Record 22 of Set 5 | banjar
# Processing Record 23 of Set 5 | belle glade
# Processing Record 24 of Set 5 | sioux lookout
# Processing Record 25 of Set 5 | londiani
# Processing Record 26 of Set 5 | honavar
# Processing Record 27 of Set 5 | namatanai
# Processing Record 28 of Set 5 | iquitos
# Processing Record 29 of Set 5 | jalu
# Processing Record 30 of Set 5 | longyearbyen
# Processing Record 31 of Set 5 | samagaltay
# Processing Record 32 of Set 5 | qaanaaq
# Processing Record 33 of Set 5 | luderitz
# Processing Record 34 of Set 5 | katangli
# Processing Record 35 of Set 5 | ribeira grande
# Processing Record 36 of Set 5 | sidi bu zayd
# City not found. Skipping...
# Processing Record 37 of Set 5 | kytlym
# City not found. Skipping...
# Processing Record 38 of Set 5 | lenart
# Processing Record 39 of Set 5 | bambous virieux
# Processing Record 40 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 5 | coihaique
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | georgetown
# Processing Record 44 of Set 5 | alofi
# Processing Record 45 of Set 5 | finschhafen
# Processing Record 46 of Set 5 | springdale
# Processing Record 47 of Set 5 | dingle
# Processing Record 48 of Set 5 | chauk
# Processing Record 49 of Set 5 | padang
# Processing Record 50 of Set 5 | haines junction
# Processing Record 1 of Set 6 | yenagoa
# Processing Record 2 of Set 6 | ferzikovo
# Processing Record 3 of Set 6 | chuy
# Processing Record 4 of Set 6 | angoche
# Processing Record 5 of Set 6 | maun
# Processing Record 6 of Set 6 | mayumba
# Processing Record 7 of Set 6 | bredasdorp
# Processing Record 8 of Set 6 | sao joao da barra
# Processing Record 9 of Set 6 | marshall
# Processing Record 10 of Set 6 | port blair
# Processing Record 11 of Set 6 | tasiilaq
# Processing Record 12 of Set 6 | opuwo
# Processing Record 13 of Set 6 | mantua
# Processing Record 14 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 6 | angatuba
# Processing Record 16 of Set 6 | moose factory
# Processing Record 17 of Set 6 | nautla
# Processing Record 18 of Set 6 | quepos
# Processing Record 19 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 6 | vao
# Processing Record 21 of Set 6 | plettenberg bay
# Processing Record 22 of Set 6 | gorno-altaysk
# Processing Record 23 of Set 6 | sao filipe
# Processing Record 24 of Set 6 | baykit
# Processing Record 25 of Set 6 | lemoore
# Processing Record 26 of Set 6 | sitka
# Processing Record 27 of Set 6 | marang
# Processing Record 28 of Set 6 | preobrazheniye
# Processing Record 29 of Set 6 | takoradi
# Processing Record 30 of Set 6 | vila franca do campo
# Processing Record 31 of Set 6 | rock springs
# Processing Record 32 of Set 6 | soskovo
# Processing Record 33 of Set 6 | kharan
# Processing Record 34 of Set 6 | kruisfontein
# Processing Record 35 of Set 6 | piro
# Processing Record 36 of Set 6 | ketchikan
# Processing Record 37 of Set 6 | constitucion
# Processing Record 38 of Set 6 | susaki
# Processing Record 39 of Set 6 | banda aceh
# Processing Record 40 of Set 6 | alpena
# Processing Record 41 of Set 6 | san-pedro
# Processing Record 42 of Set 6 | yeppoon
# Processing Record 43 of Set 6 | tual
# Processing Record 44 of Set 6 | gallup
# Processing Record 45 of Set 6 | angoram
# Processing Record 46 of Set 6 | changping
# Processing Record 47 of Set 6 | verkhoyansk
# Processing Record 48 of Set 6 | flinders
# Processing Record 49 of Set 6 | san patricio
# Processing Record 50 of Set 6 | yarmouth
# Processing Record 1 of Set 7 | canoinhas
# Processing Record 2 of Set 7 | gat
# Processing Record 3 of Set 7 | swellendam
# Processing Record 4 of Set 7 | shimanovsk
# Processing Record 5 of Set 7 | artyom
# Processing Record 6 of Set 7 | tuatapere
# Processing Record 7 of Set 7 | naze
# Processing Record 8 of Set 7 | meulaboh
# Processing Record 9 of Set 7 | guerrero negro
# Processing Record 10 of Set 7 | toora-khem
# Processing Record 11 of Set 7 | zykovo
# Processing Record 12 of Set 7 | nome
# Processing Record 13 of Set 7 | mercedes
# Processing Record 14 of Set 7 | antofagasta
# Processing Record 15 of Set 7 | chilliwack
# Processing Record 16 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 7 | saravena
# Processing Record 18 of Set 7 | diego de almagro
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | senador jose porfirio
# Processing Record 21 of Set 7 | black forest
# Processing Record 22 of Set 7 | mago
# Processing Record 23 of Set 7 | half moon bay
# Processing Record 24 of Set 7 | acuna
# City not found. Skipping...
# Processing Record 25 of Set 7 | bonthe
# Processing Record 26 of Set 7 | santiago de cao
# Processing Record 27 of Set 7 | klaksvik
# Processing Record 28 of Set 7 | varhaug
# Processing Record 29 of Set 7 | san ramon
# Processing Record 30 of Set 7 | fairbanks
# Processing Record 31 of Set 7 | atar
# Processing Record 32 of Set 7 | khabary
# Processing Record 33 of Set 7 | khatanga
# Processing Record 34 of Set 7 | alekseyevsk
# Processing Record 35 of Set 7 | asyut
# Processing Record 36 of Set 7 | abha
# Processing Record 37 of Set 7 | bilma
# Processing Record 38 of Set 7 | victoria
# Processing Record 39 of Set 7 | san juan tecuaco
# Processing Record 40 of Set 7 | egvekinot
# Processing Record 41 of Set 7 | korla
# Processing Record 42 of Set 7 | rio grande
# Processing Record 43 of Set 7 | ambon
# Processing Record 44 of Set 7 | truth or consequences
# Processing Record 45 of Set 7 | pahrump
# Processing Record 46 of Set 7 | zelenogorskiy
# Processing Record 47 of Set 7 | hamilton
# Processing Record 48 of Set 7 | nanortalik
# Processing Record 49 of Set 7 | west wendover
# Processing Record 50 of Set 7 | kaoma
# Processing Record 1 of Set 8 | dikson
# Processing Record 2 of Set 8 | nouadhibou
# Processing Record 3 of Set 8 | mount isa
# Processing Record 4 of Set 8 | vanimo
# Processing Record 5 of Set 8 | la palma
# Processing Record 6 of Set 8 | castro
# Processing Record 7 of Set 8 | broken hill
# Processing Record 8 of Set 8 | ilulissat
# Processing Record 9 of Set 8 | marawi
# Processing Record 10 of Set 8 | sola
# Processing Record 11 of Set 8 | kiruna
# Processing Record 12 of Set 8 | buin
# Processing Record 13 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 8 | taltal
# Processing Record 15 of Set 8 | teya
# Processing Record 16 of Set 8 | lata
# Processing Record 17 of Set 8 | quatre cocos
# Processing Record 18 of Set 8 | concepcion
# Processing Record 19 of Set 8 | oregon
# Processing Record 20 of Set 8 | turukhansk
# Processing Record 21 of Set 8 | boa vista
# Processing Record 22 of Set 8 | solnechnyy
# Processing Record 23 of Set 8 | bathsheba
# Processing Record 24 of Set 8 | biltine
# Processing Record 25 of Set 8 | salinopolis
# Processing Record 26 of Set 8 | ballina
# Processing Record 27 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 8 | whitianga
# Processing Record 29 of Set 8 | kenscoff
# Processing Record 30 of Set 8 | yashkino
# Processing Record 31 of Set 8 | shenjiamen
# Processing Record 32 of Set 8 | oistins
# Processing Record 33 of Set 8 | cornesti
# Processing Record 34 of Set 8 | batagay-alyta
# Processing Record 35 of Set 8 | idlib
# Processing Record 36 of Set 8 | ville-marie
# Processing Record 37 of Set 8 | shingu
# Processing Record 38 of Set 8 | denizli
# Processing Record 39 of Set 8 | smithers
# Processing Record 40 of Set 8 | sindor
# Processing Record 41 of Set 8 | inirida
# Processing Record 42 of Set 8 | marienburg
# Processing Record 43 of Set 8 | damietta
# Processing Record 44 of Set 8 | hambantota
# Processing Record 45 of Set 8 | sinegorskiy
# Processing Record 46 of Set 8 | salinas
# Processing Record 47 of Set 8 | khaniotis
# Processing Record 48 of Set 8 | bela
# Processing Record 49 of Set 8 | progreso
# Processing Record 50 of Set 8 | namtsy
# Processing Record 1 of Set 9 | homer
# Processing Record 2 of Set 9 | sinnamary
# Processing Record 3 of Set 9 | olinda
# Processing Record 4 of Set 9 | tazovskiy
# Processing Record 5 of Set 9 | mitu
# Processing Record 6 of Set 9 | petrovskaya
# Processing Record 7 of Set 9 | avera
# Processing Record 8 of Set 9 | lithgow
# Processing Record 9 of Set 9 | sinfra
# Processing Record 10 of Set 9 | alcaniz
# Processing Record 11 of Set 9 | griffith
# Processing Record 12 of Set 9 | borovoy
# Processing Record 13 of Set 9 | miyako
# Processing Record 14 of Set 9 | sigli
# Processing Record 15 of Set 9 | batagay
# Processing Record 16 of Set 9 | baker city
# Processing Record 17 of Set 9 | khandyga
# Processing Record 18 of Set 9 | akyab
# Processing Record 19 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 20 of Set 9 | morro bay
# Processing Record 21 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 9 | rocha
# Processing Record 23 of Set 9 | kropotkin
# Processing Record 24 of Set 9 | luorong
# Processing Record 25 of Set 9 | tecoanapa
# Processing Record 26 of Set 9 | srednekolymsk
# Processing Record 27 of Set 9 | leningradskiy
# Processing Record 28 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 9 | seoul
# Processing Record 30 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 9 | qaqortoq
# Processing Record 32 of Set 9 | strathpeffer
# Processing Record 33 of Set 9 | nurota
# Processing Record 34 of Set 9 | nalut
# Processing Record 35 of Set 9 | qasigiannguit
# Processing Record 36 of Set 9 | menongue
# Processing Record 37 of Set 9 | tonj
# Processing Record 38 of Set 9 | shubarkuduk
# Processing Record 39 of Set 9 | port-gentil
# Processing Record 40 of Set 9 | manitouwadge
# Processing Record 41 of Set 9 | pietersburg
# Processing Record 42 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 43 of Set 9 | north platte
# Processing Record 44 of Set 9 | port hardy
# Processing Record 45 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 9 | ati
# Processing Record 47 of Set 9 | shihezi
# Processing Record 48 of Set 9 | kangaatsiaq
# Processing Record 49 of Set 9 | lixourion
# Processing Record 50 of Set 9 | verkhoturye
# Processing Record 1 of Set 10 | simao
# Processing Record 2 of Set 10 | chichihualco
# Processing Record 3 of Set 10 | lompoc
# Processing Record 4 of Set 10 | cheyenne
# Processing Record 5 of Set 10 | lahat
# Processing Record 6 of Set 10 | buala
# Processing Record 7 of Set 10 | aksarka
# Processing Record 8 of Set 10 | ostersund
# Processing Record 9 of Set 10 | ravar
# Processing Record 10 of Set 10 | tukrah
# Processing Record 11 of Set 10 | manuk mangkaw
# Processing Record 12 of Set 10 | viesca
# Processing Record 13 of Set 10 | shyroke
# Processing Record 14 of Set 10 | yinchuan
# Processing Record 15 of Set 10 | heihe
# Processing Record 16 of Set 10 | guymon
# Processing Record 17 of Set 10 | rio gallegos
# Processing Record 18 of Set 10 | corpus christi
# Processing Record 19 of Set 10 | neiafu
# Processing Record 20 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 10 | jinchang
# Processing Record 22 of Set 10 | la romana
# Processing Record 23 of Set 10 | te anau
# Processing Record 24 of Set 10 | yazd
# Processing Record 25 of Set 10 | burica
# City not found. Skipping...
# Processing Record 26 of Set 10 | margate
# Processing Record 27 of Set 10 | goure
# Processing Record 28 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 10 | seymchan
# Processing Record 30 of Set 10 | evensk
# Processing Record 31 of Set 10 | richard toll
# City not found. Skipping...
# Processing Record 32 of Set 10 | nantucket
# Processing Record 33 of Set 10 | san matias
# Processing Record 34 of Set 10 | grindavik
# Processing Record 35 of Set 10 | fort nelson
# Processing Record 36 of Set 10 | kavaratti
# Processing Record 37 of Set 10 | verkhovye
# Processing Record 38 of Set 10 | suez
# Processing Record 39 of Set 10 | ingham
# Processing Record 40 of Set 10 | rawson
# Processing Record 41 of Set 10 | naryan-mar
# Processing Record 42 of Set 10 | bosanska gradiska
# Processing Record 43 of Set 10 | necochea
# Processing Record 44 of Set 10 | puri
# Processing Record 45 of Set 10 | gidam
# Processing Record 46 of Set 10 | tchaourou
# Processing Record 47 of Set 10 | lebyazhye
# Processing Record 48 of Set 10 | trail
# Processing Record 49 of Set 10 | dwarka
# Processing Record 50 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 11 | ulaanbaatar
# Processing Record 2 of Set 11 | karratha
# Processing Record 3 of Set 11 | brasileia
# Processing Record 4 of Set 11 | tezu
# Processing Record 5 of Set 11 | voyvozh
# Processing Record 6 of Set 11 | galle
# Processing Record 7 of Set 11 | cervo
# Processing Record 8 of Set 11 | jesi
# Processing Record 9 of Set 11 | kieta
# Processing Record 10 of Set 11 | bahia blanca
# Processing Record 11 of Set 11 | kukes
# Processing Record 12 of Set 11 | nemuro
# Processing Record 13 of Set 11 | port hedland
# Processing Record 14 of Set 11 | pisco
# Processing Record 15 of Set 11 | shalinskoye
# Processing Record 16 of Set 11 | thaba nchu
# Processing Record 17 of Set 11 | camacha
# Processing Record 18 of Set 11 | suleja
# Processing Record 19 of Set 11 | tiarei
# Processing Record 20 of Set 11 | qunduz
# Processing Record 21 of Set 11 | bereda
# Processing Record 22 of Set 11 | bulolo
# Processing Record 23 of Set 11 | ahipara
# Processing Record 24 of Set 11 | issoire
# Processing Record 25 of Set 11 | bolshaya atnya
# City not found. Skipping...
# Processing Record 26 of Set 11 | semnan
# Processing Record 27 of Set 11 | eustaquio lopez
# Processing Record 28 of Set 11 | eyrarbakki
# Processing Record 29 of Set 11 | singaraja
# Processing Record 30 of Set 11 | thayetmyo
# Processing Record 31 of Set 11 | wajima
# Processing Record 32 of Set 11 | vaasa
# Processing Record 33 of Set 11 | umm kaddadah
# Processing Record 34 of Set 11 | anadyr
# Processing Record 35 of Set 11 | aswan
# Processing Record 36 of Set 11 | tokzar
# City not found. Skipping...
# Processing Record 37 of Set 11 | datong
# Processing Record 38 of Set 11 | ploufragan
# Processing Record 39 of Set 11 | mildura
# Processing Record 40 of Set 11 | panzhihua
# Processing Record 41 of Set 11 | bridlington
# Processing Record 42 of Set 11 | san quintin
# Processing Record 43 of Set 11 | huilong
# Processing Record 44 of Set 11 | ulkan
# Processing Record 45 of Set 11 | talnakh
# Processing Record 46 of Set 11 | zhaotong
# Processing Record 47 of Set 11 | arroyo
# Processing Record 48 of Set 11 | teahupoo
# Processing Record 49 of Set 11 | pringsewu
# Processing Record 50 of Set 11 | khao wong
# Processing Record 1 of Set 12 | shetpe
# Processing Record 2 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 12 | itarema
# Processing Record 4 of Set 12 | senftenberg
# Processing Record 5 of Set 12 | grand gaube
# Processing Record 6 of Set 12 | taburao
# City not found. Skipping...
# Processing Record 7 of Set 12 | molina
# Processing Record 8 of Set 12 | tsiroanomandidy
# Processing Record 9 of Set 12 | acapulco
# Processing Record 10 of Set 12 | hofn
# Processing Record 11 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 12 of Set 12 | sydney
# Processing Record 13 of Set 12 | mana
# Processing Record 14 of Set 12 | les escoumins
# Processing Record 15 of Set 12 | cururupu
# Processing Record 16 of Set 12 | yining
# Processing Record 17 of Set 12 | okato
# Processing Record 18 of Set 12 | hurghada
# Processing Record 19 of Set 12 | eureka
# Processing Record 20 of Set 12 | mananjary
# Processing Record 21 of Set 12 | cosala
# Processing Record 22 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 23 of Set 12 | alice springs
# Processing Record 24 of Set 12 | peniche
# Processing Record 25 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 26 of Set 12 | geraldton
# Processing Record 27 of Set 12 | rurrenabaque
# Processing Record 28 of Set 12 | muli
# Processing Record 29 of Set 12 | khorixas
# Processing Record 30 of Set 12 | pochutla
# Processing Record 31 of Set 12 | vila
# Processing Record 32 of Set 12 | teguise
# Processing Record 33 of Set 12 | camacupa
# Processing Record 34 of Set 12 | chaumont
# Processing Record 35 of Set 12 | matadi
# Processing Record 36 of Set 12 | kindu
# Processing Record 37 of Set 12 | vestmannaeyjar
# Processing Record 38 of Set 12 | ornskoldsvik
# Processing Record 39 of Set 12 | saint-raphael
# Processing Record 40 of Set 12 | asfi
# Processing Record 41 of Set 12 | carutapera
# Processing Record 42 of Set 12 | fuyu
# Processing Record 43 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 12 | kirakira
# Processing Record 45 of Set 12 | goundi
# Processing Record 46 of Set 12 | quthing
# Processing Record 47 of Set 12 | lubango
# Processing Record 48 of Set 12 | waitati
# Processing Record 49 of Set 12 | adrar
# Processing Record 50 of Set 12 | san rafael
# Processing Record 1 of Set 13 | itoman
# Processing Record 2 of Set 13 | tres arroyos
# Processing Record 3 of Set 13 | baruun-urt
# Processing Record 4 of Set 13 | vierzon
# Processing Record 5 of Set 13 | sorland
# Processing Record 6 of Set 13 | fortuna
# Processing Record 7 of Set 13 | revelstoke
# Processing Record 8 of Set 13 | bud
# Processing Record 9 of Set 13 | tigzirt
# Processing Record 10 of Set 13 | amazar
# Processing Record 11 of Set 13 | fernie
# Processing Record 12 of Set 13 | aktau
# Processing Record 13 of Set 13 | luena
# Processing Record 14 of Set 13 | simpang
# Processing Record 15 of Set 13 | mariestad
# Processing Record 16 of Set 13 | togul
# Processing Record 17 of Set 13 | ocampo
# Processing Record 18 of Set 13 | amapa
# Processing Record 19 of Set 13 | belyy yar
# Processing Record 20 of Set 13 | la paz
# Processing Record 21 of Set 13 | oktyabrskoye
# Processing Record 22 of Set 13 | chernolesskoye
# Processing Record 23 of Set 13 | mount gambier
# Processing Record 24 of Set 13 | moba
# Processing Record 25 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 13 | bulgan
# Processing Record 27 of Set 13 | inuvik
# Processing Record 28 of Set 13 | santa maria
# Processing Record 29 of Set 13 | jinxi
# Processing Record 30 of Set 13 | kulhudhuffushi
# Processing Record 31 of Set 13 | ballater
# Processing Record 32 of Set 13 | araguatins
# City not found. Skipping...
# Processing Record 33 of Set 13 | maceio
# Processing Record 34 of Set 13 | lusambo
# Processing Record 35 of Set 13 | taoudenni
# Processing Record 36 of Set 13 | bijar
# Processing Record 37 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 38 of Set 13 | mugumu
# Processing Record 39 of Set 13 | loma bonita
# Processing Record 40 of Set 13 | miastko
# Processing Record 41 of Set 13 | port-cartier
# Processing Record 42 of Set 13 | atwater
# Processing Record 43 of Set 13 | harrison
# Processing Record 44 of Set 13 | xambioa
# Processing Record 45 of Set 13 | deputatskiy
# Processing Record 46 of Set 13 | strezhevoy
# Processing Record 47 of Set 13 | assiniboia
# Processing Record 48 of Set 13 | atambua
# Processing Record 49 of Set 13 | hailar
# Processing Record 50 of Set 13 | novikovo
# Processing Record 1 of Set 14 | saint anthony
# Processing Record 2 of Set 14 | bitung
# Processing Record 3 of Set 14 | byron bay
# Processing Record 4 of Set 14 | redcar
# Processing Record 5 of Set 14 | waddan
# Processing Record 6 of Set 14 | sawakin
# Processing Record 7 of Set 14 | kayes
# Processing Record 8 of Set 14 | san nicolas
# Processing Record 9 of Set 14 | juegang
# Processing Record 10 of Set 14 | beloha
# Processing Record 11 of Set 14 | aleksandrov gay
# Processing Record 12 of Set 14 | caravelas
# Processing Record 13 of Set 14 | sur
# Processing Record 14 of Set 14 | west bay
# Processing Record 15 of Set 14 | izhma
# Processing Record 16 of Set 14 | chernyshevskiy
# Processing Record 17 of Set 14 | senanga
# Processing Record 18 of Set 14 | auki
# Processing Record 19 of Set 14 | north bend
# Processing Record 20 of Set 14 | odweyne
# Processing Record 21 of Set 14 | mehran
# Processing Record 22 of Set 14 | larsnes
# Processing Record 23 of Set 14 | singaparna
# Processing Record 24 of Set 14 | barmer
# Processing Record 25 of Set 14 | saint-jerome
# Processing Record 26 of Set 14 | lorengau
# Processing Record 27 of Set 14 | baft
# Processing Record 28 of Set 14 | payo
# Processing Record 29 of Set 14 | caraballeda
# Processing Record 30 of Set 14 | zaranj
# Processing Record 31 of Set 14 | coquimbo
# Processing Record 32 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 33 of Set 14 | bandarbeyla
# Processing Record 34 of Set 14 | karpogory
# Processing Record 35 of Set 14 | batemans bay
# Processing Record 36 of Set 14 | gorkovskoye
# City not found. Skipping...
# Processing Record 37 of Set 14 | beringovskiy
# Processing Record 38 of Set 14 | baijiantan
# Processing Record 39 of Set 14 | porto belo
# Processing Record 40 of Set 14 | olavarria
# Processing Record 41 of Set 14 | boyolangu
# Processing Record 42 of Set 14 | zhangjiakou
# Processing Record 43 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 44 of Set 14 | fomboni
# Processing Record 45 of Set 14 | silopi
# Processing Record 46 of Set 14 | labuhan
# Processing Record 47 of Set 14 | santa maria da boa vista
# Processing Record 48 of Set 14 | crewe
# Processing Record 49 of Set 14 | cacu
# Processing Record 50 of Set 14 | agadez
# Processing Record 1 of Set 15 | aitape
# Processing Record 2 of Set 15 | hals
# Processing Record 3 of Set 15 | athabasca
# Processing Record 4 of Set 15 | cayenne
# Processing Record 5 of Set 15 | estrela
# Processing Record 6 of Set 15 | ewo
# Processing Record 7 of Set 15 | port moresby
# Processing Record 8 of Set 15 | leh
# Processing Record 9 of Set 15 | mandalgovi
# Processing Record 10 of Set 15 | mahon
# Processing Record 11 of Set 15 | kasongo-lunda
# Processing Record 12 of Set 15 | abu kamal
# Processing Record 13 of Set 15 | mbini
# Processing Record 14 of Set 15 | kushima
# Processing Record 15 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 15 | bilibino
# Processing Record 17 of Set 15 | walvis bay
# Processing Record 18 of Set 15 | maniitsoq
# Processing Record 19 of Set 15 | baherden
# Processing Record 20 of Set 15 | darnah
# Processing Record 21 of Set 15 | orebro
# Processing Record 22 of Set 15 | liverpool
# Processing Record 23 of Set 15 | mogadishu
# Processing Record 24 of Set 15 | gamba
# Processing Record 25 of Set 15 | lethem
# Processing Record 26 of Set 15 | ponta delgada
# Processing Record 27 of Set 15 | vestmanna
# Processing Record 28 of Set 15 | wuwei
# Processing Record 29 of Set 15 | sar-e pul
# Processing Record 30 of Set 15 | kuala terengganu
# Processing Record 31 of Set 15 | thinadhoo
# Processing Record 32 of Set 15 | lekoni
# Processing Record 33 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 34 of Set 15 | sabha
# Processing Record 35 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 36 of Set 15 | dzhebariki-khaya
# Processing Record 37 of Set 15 | firminy
# Processing Record 38 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 39 of Set 15 | ust-nera
# Processing Record 40 of Set 15 | pandan
# Processing Record 41 of Set 15 | yulara
# Processing Record 42 of Set 15 | pingliang
# Processing Record 43 of Set 15 | fatehgarh
# Processing Record 44 of Set 15 | hobyo
# Processing Record 45 of Set 15 | marzuq
# Processing Record 46 of Set 15 | inhambane
# Processing Record 47 of Set 15 | guiglo
# Processing Record 48 of Set 15 | jiangyou
# Processing Record 49 of Set 15 | betare oya
# Processing Record 50 of Set 15 | bobcaygeon
# Processing Record 1 of Set 16 | miandrivazo
# Processing Record 2 of Set 16 | talcahuano
# Processing Record 3 of Set 16 | isla mujeres
# Processing Record 4 of Set 16 | wanning
# Processing Record 5 of Set 16 | pentecoste
# Processing Record 6 of Set 16 | henties bay
# Processing Record 7 of Set 16 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 16 | gravdal
# Processing Record 9 of Set 16 | cordoba
# Processing Record 10 of Set 16 | mayo
# Processing Record 11 of Set 16 | ileza
# Processing Record 12 of Set 16 | sabang
# Processing Record 13 of Set 16 | vorukh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Albany      US  42.60  -73.97     75.99        32           7
# 1        Arrecife      ES  28.96  -13.55     77.00        78          20
# 2    Norman Wells      CA  65.28 -126.83     46.40        70          75
# 3         Ushuaia      AR -54.80  -68.30     46.40        82          75
# 4       Saskylakh      RU  71.92  114.08     37.22        88          66
# ..            ...     ...    ...     ...       ...       ...         ...
# 698       Cordoba      AR -31.41  -64.18     68.00        48          20
# 699          Mayo      US  38.89  -76.51     79.00        44           1
# 700         Ileza      RU  61.05   43.90     55.60        87          98
# 701        Sabang      ID   5.89   95.32     83.68        72          99
# 702        Vorukh      TJ  39.85   70.58     64.58        32           1
#
#      Wind Speed Current Description
# 0          3.00           clear sky
# 1          4.70          few clouds
# 2          2.24       broken clouds
# 3         19.46         shower rain
# 4          9.35       broken clouds
# ..          ...                 ...
# 698        6.93          few clouds
# 699        6.93           clear sky
# 700        6.80     overcast clouds
# 701       17.96          light rain
# 702        2.98           clear sky
#
# [703 rows x 9 columns]

# %%
#Reorder columns 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Albany      US  42.60  -73.97     75.99        32           7
# 1        Arrecife      ES  28.96  -13.55     77.00        78          20
# 2    Norman Wells      CA  65.28 -126.83     46.40        70          75
# 3         Ushuaia      AR -54.80  -68.30     46.40        82          75
# 4       Saskylakh      RU  71.92  114.08     37.22        88          66
# ..            ...     ...    ...     ...       ...       ...         ...
# 698       Cordoba      AR -31.41  -64.18     68.00        48          20
# 699          Mayo      US  38.89  -76.51     79.00        44           1
# 700         Ileza      RU  61.05   43.90     55.60        87          98
# 701        Sabang      ID   5.89   95.32     83.68        72          99
# 702        Vorukh      TJ  39.85   70.58     64.58        32           1
#
#      Wind Speed Current Description
# 0          3.00           clear sky
# 1          4.70          few clouds
# 2          2.24       broken clouds
# 3         19.46         shower rain
# 4          9.35       broken clouds
# ..          ...                 ...
# 698        6.93          few clouds
# 699        6.93           clear sky
# 700        6.80     overcast clouds
# 701       17.96          light rain
# 702        2.98           clear sky
#
# [703 rows x 9 columns]

# %%
#Create an output file
output_data_file ="WeatherPy_Database.csv"
#Export city_data DF into a .CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
